# %%
fruits=["appple","banana","mango"]
print(fruits[0])
# Out:
# appple

# %%
vegetable=["brinjal","chilli"]
print(vegetable[0])
# Out:
# brinjal

# %%
student=[]
student.append("hanumanti")
student.append("megha")
print(students)
# Out:
# []

# %%
coordinates=(10,20)
print(coordinates[1])
# Out:
# 20

# %%
numbers={1,2,3,4,5,3,4,}
print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
student={
    "name":"hanumanti",
    "age":20,
    "course":"agri"
}
print(student["name"])
# Out:
# hanumanti

# %%
marks={
    "math":85,
    "science":90

}
marks["english"]=88
print(marks)
# Out:
# {'math': 85, 'science': 90, 'english': 88}
