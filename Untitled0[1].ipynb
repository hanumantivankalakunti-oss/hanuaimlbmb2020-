# %%
for i in range(2):
 for j in range(3):
  print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2

# %%
for i in range(3):
 for j in range(3):
   print ("*",end="")
print()
# Out:
# *********

# %%
rows=int(input("enter rows:"))
columns=int(input("enter columns:"))

for i in range(rows):
  for j in range(columns):
    print("#",end="")
print()
# Out:
# enter rows:2
# enter columns:4
# ########

# %%
for i in range(3):
  j=0
  while j<2:
    print(i,j)
    j+=1
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1
