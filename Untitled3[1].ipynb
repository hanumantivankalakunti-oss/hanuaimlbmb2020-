# %%
for i in range(2):
  for j in range(3):
    print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2

# %%
for i in range(1,6):
  for j in range(1,6):
    print(i*j, end="\t")
    print(i,j)
# Out:
# 1	1 1
# 2	1 2
# 3	1 3
# 4	1 4
# 5	1 5
# 2	2 1
# 4	2 2
# 6	2 3
# 8	2 4
# 10	2 5
# 3	3 1
# 6	3 2
# 9	3 3
# 12	3 4
# 15	3 5
# 4	4 1
# 8	4 2
# 12	4 3
# 16	4 4
# 20	4 5
# 5	5 1
# 10	5 2
# 15	5 3
# 20	5 4
# 25	5 5

# %%
fruit=["apple,"]
print(fruit[0])
# Out:
# apple,
